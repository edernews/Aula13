# %% [markdown]
# ### instalando a biblioteca OS ###

# %%
! pip list
# Out:
# Package           Version
# ----------------- ------------
# asttokens         2.2.1
# backcall          0.2.0
# colorama          0.4.6
# comm              0.1.4
# contourpy         1.1.1
# cycler            0.11.0
# debugpy           1.6.7.post1
# decorator         5.1.1
# EasyProcess       1.1
# entrypoint2       1.1
# et-xmlfile        1.1.0
# executing         1.2.0
# flatbuffers       23.5.26
# fonttools         4.42.1
# ipykernel         6.25.1
# ipython           8.14.0
# jedi              0.19.0
# jupyter_client    8.3.0
# jupyter_core      5.3.1
# kiwisolver        1.4.5
# matplotlib        3.8.0
# matplotlib-inline 0.1.6
# MouseInfo         0.1.3
# mpmath            1.3.0
# mss               9.0.1
# nest-asyncio      1.5.7
# numpy             1.24.2
# openpyxl          3.1.2
# packaging         23.1
# pandas            2.1.0
# parso             0.8.3
# pickleshare       0.7.5
# Pillow            10.0.0
# pip               22.3
# platformdirs      3.10.0
# ...

# %%
### importando as Bibliotecas 

import pandas as pd ### Pandas 
import os as os #### 


### criar variavel para armazenar o caminho do diretorio com os arquivos 

dir_path = 'C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\arquivos\\003 - Arquivos\\filiais\\'

### CRIAR UM LISTA PARA PEGAR TODOS OS ARQUIVOS E LISTAR EM UMA SÓ ###

res = []

for path in os.listdir(dir_path):
    if os.path.isfile(dir_path + path):
        res.append(dir_path + path)
        
res

###os.listdir(dir_path)
# Out:
# ['C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\arquivos\\003 - Arquivos\\filiais\\Funcionários - Faria Lima.xlsx',
#  'C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\arquivos\\003 - Arquivos\\filiais\\Funcionários - Matriz.xlsx',
#  'C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\arquivos\\003 - Arquivos\\filiais\\Funcionários - Paulista.xlsx',
#  'C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\arquivos\\003 - Arquivos\\filiais\\Funcionários - Pompéia.xlsx']

# %%
# Criar uma lista vazia para armazenar os caminhos completos
res = []

#
for path in os.listdir(dir_path):
    # Verificar se é um arquivo válido
    if os.path.isfile(dir_path + path):
        res.append(dir_path + path)

res
# Out:
# ['C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\arquivos\\003 - Arquivos\\filiais\\Funcionários - Faria Lima.xlsx',
#  'C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\arquivos\\003 - Arquivos\\filiais\\Funcionários - Matriz.xlsx',
#  'C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\arquivos\\003 - Arquivos\\filiais\\Funcionários - Paulista.xlsx',
#  'C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\arquivos\\003 - Arquivos\\filiais\\Funcionários - Pompéia.xlsx']

# %%
for file in res:
    df_1 = pd.read_excel(file)
    file_combined = pd.concat([file_combined,df_1])

file_combined
# Out:
#    Matrícula                   Nome     Gênero  \
# 0    00390-3       Beatriz de Matos   Feminino
# 1    00390-9      Clara de Oliveira   Feminino
# 2    00391-8      Louise de Almeida   Feminino
# 3    00393-0   Diogo da Silva Lopes  Masculino
# 4    00393-1  Maria Alice Fernandes   Feminino
# ..       ...                    ...        ...
# 94   00602-4          Luana Marques   Feminino
# 95   00604-3           Flávio Lopes  Masculino
# 96   00606-1   Luiz Fernando Simões  Masculino
# 97   00608-1         Gustavo Araújo  Masculino
# 98   00609-4       Benjamim Machado  Masculino
#
#                                Cargo              Departamento  \
# 0             Auxiliar de Manutenção                Manutenção
# 1                Auxiliar de Compras                   Compras
# 2                Auxiliar de Compras                   Compras
# 3   Assistente de Crédito e Cobrança        Crédito e Cobrança
# 4                 Programador de PCP                       PCP
# ...

# %%
dir_final = 'C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\arquivos\\003 - Arquivos\\filiais\\'

arquivo_final = 'arquivo_final.xlsx'

file_combined.to_excel(dir_final + arquivo_final)
